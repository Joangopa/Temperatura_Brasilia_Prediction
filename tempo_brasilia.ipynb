# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

# %%
df2020 = pd.read_csv("dados/INMET_CO_DF_A001_BRASILIA_01-01-2020_A_31-12-2020.CSV", decimal=',', thousands='.', sep=";", index_col='Data')

# %%
df2020.columns
# Out:
# Index(['Hora UTC', 'PRECIPITA��O TOTAL, HOR�RIO (mm)',
#        'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
#        'PRESS�O ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
#        'PRESS�O ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
#        'RADIACAO GLOBAL (Kj/m�)',
#        'TEMPERATURA DO AR - BULBO SECO, HORARIA (�C)',
#        'TEMPERATURA DO PONTO DE ORVALHO (�C)',
#        'TEMPERATURA MAXIMA NA HORA ANT. (AUT) (°C)',
#        'TEMPERATURA MINIMA NA HORA ANT. (AUT) (°C)',
#        'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (�C)',
#        'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (�C)',
#        'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
#        'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
#        'UMIDADE RELATIVA DO AR, HORARIA (%)',
#        'VENTO, DIRE��O HORARIA (gr) (� (gr))', 'VENTO, RAJADA MAXIMA (m/s)',
#        'VENTO, VELOCIDADE HORARIA (m/s)', 'Unnamed: 19'],
#       dtype='object')

# %%
df2020.rename(columns={'TEMPERATURA MAXIMA NA HORA ANT. (AUT) (°C)': 'TEMP'}, inplace=True)
temp_max_2020 = df2020['TEMP'].copy()
temp_max_2020.index = pd.to_datetime(temp_max_2020.index, format='%Y/%m/%d')

# %%
temp_max_2020
# Out:
# Data
# 2020-01-01    20.2
# 2020-01-01    20.0
# 2020-01-01    20.1
# 2020-01-01    20.2
# 2020-01-01    19.8
#               ...
# 2020-12-31    29.3
# 2020-12-31    28.1
# 2020-12-31    23.6
# 2020-12-31    23.6
# 2020-12-31    22.3
# Name: TEMP, Length: 8784, dtype: float64

# %%
df2021 = pd.read_csv("dados/INMET_CO_DF_A001_BRASILIA_01-01-2021_A_31-12-2021.CSV", decimal=',', thousands='.', sep=";", index_col='Data', encoding='latin1')

# %%
df2021.columns
# Out:
# Index(['Hora UTC', 'PRECIPITAï¿½ï¿½O TOTAL, HORï¿½RIO (mm)',
#        'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
#        'PRESSï¿½O ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
#        'PRESSï¿½O ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
#        'RADIACAO GLOBAL (Kj/mï¿½)',
#        'TEMPERATURA DO AR - BULBO SECO, HORARIA (ï¿½C)',
#        'TEMPERATURA DO PONTO DE ORVALHO (ï¿½C)',
#        'TEMPERATURA Mï¿½XIMA NA HORA ANT. (AUT) (ï¿½C)',
#        'TEMPERATURA Mï¿½NIMA NA HORA ANT. (AUT) (ï¿½C)',
#        'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (ï¿½C)',
#        'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (ï¿½C)',
#        'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
#        'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
#        'UMIDADE RELATIVA DO AR, HORARIA (%)',
#        'VENTO, DIREï¿½ï¿½O HORARIA (gr) (ï¿½ (gr))',
#        'VENTO, RAJADA MAXIMA (m/s)', 'VENTO, VELOCIDADE HORARIA (m/s)',
#        'Unnamed: 19'],
#       dtype='object')

# %%
df2021.rename(columns={'TEMPERATURA Mï¿½XIMA NA HORA ANT. (AUT) (ï¿½C)': 'TEMP'}, inplace=True)
temp_max_2021 = df2021['TEMP'].copy()
temp_max_2021.index = pd.to_datetime(temp_max_2021.index, format='%Y/%m/%d')

# %%
df2022 = pd.read_csv("dados/INMET_CO_DF_A001_BRASILIA_01-01-2022_A_31-12-2022.CSV", decimal=',', thousands='.', sep=";", index_col='Data', encoding='latin1')
df2022.rename(columns={'TEMPERATURA Mï¿½XIMA NA HORA ANT. (AUT) (ï¿½C)': 'TEMP'}, inplace=True)
temp_max_2022 = df2022['TEMP'].copy()
temp_max_2022.index = pd.to_datetime(temp_max_2022.index, format='%Y/%m/%d')

# %%
df2023 = pd.read_csv("dados/INMET_CO_DF_A001_BRASILIA_01-01-2023_A_31-12-2023.CSV", decimal=',', thousands='.', sep=";", index_col='Data', encoding='latin1')
df2023.rename(columns={'TEMPERATURA Mï¿½XIMA NA HORA ANT. (AUT) (ï¿½C)': 'TEMP'}, inplace=True)
temp_max_2023 = df2023['TEMP'].copy()
temp_max_2023.index = pd.to_datetime(temp_max_2023.index, format='%Y/%m/%d')

# %%
df2024 = pd.read_csv("dados/INMET_CO_DF_A001_BRASILIA_01-01-2024_A_31-05-2024.CSV", decimal=',', thousands='.', sep=";", index_col='Data', encoding='latin1')
df2024.rename(columns={'TEMPERATURA Mï¿½XIMA NA HORA ANT. (AUT) (ï¿½C)': 'TEMP'}, inplace=True)
temp_max_2024 = df2024['TEMP'].copy()
temp_max_2024.index = pd.to_datetime(temp_max_2024.index, format='%Y/%m/%d')

# %%
temp_max_combined = pd.concat([temp_max_2020, temp_max_2021, temp_max_2022, temp_max_2023, temp_max_2024])

# %%
temp_max_combined.dropna(inplace=True)

# %%
temp_max_combined = temp_max_combined.sort_index()

# %%
temp_max_combined.describe()
# Out:
# count    38692.000000
# mean        22.254058
# std          4.052434
# min          6.000000
# 25%         19.300000
# 50%         21.800000
# 75%         25.200000
# max         36.500000
# Name: TEMP, dtype: float64

# %%
plt.figure(figsize=(20, 10))
temp_max_combined.plot()
# Out:
# <Axes: xlabel='Data'>

# %%
temp_max_combined.to_csv('temp_2020_2024.csv')

# %%
dd = pd.read_csv('temp_2020_2024.csv', index_col='Data')
dd
# Out:
#             TEMP
# Data
# 2020-01-01  20.2
# 2020-01-01  20.0
# 2020-01-01  20.1
# 2020-01-01  20.2
# 2020-01-01  19.8
# ...          ...
# 2024-05-31  25.6
# 2024-05-31  25.3
# 2024-05-31  23.9
# 2024-05-31  22.0
# 2024-05-31  21.1
#
# [38692 rows x 1 columns]

# %%
# [[[1], [2], [3], [4], [5]]] [6]
# [[[2], [3], [4], [5], [6]]] [7]
# [[[3], [4], [5], [6], [7]]] [8]

def df_to_X_y(df, window_size=5):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [[a] for a in df_as_np[i:i+window_size]]
    X.append(row)
    label = df_as_np[i+window_size]
    y.append(label)
  return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 5
X1, y1 = df_to_X_y(temp_max_combined, WINDOW_SIZE)
X1.shape, y1.shape
# Out:
# ((38687, 5, 1), (38687,))

# %%
X_train1, y_train1 = X1[:30000], y1[:30000]
X_val1, y_val1 = X1[30000:35000], y1[30000:35000]
X_test1, y_test1 = X1[35000:], y1[35000:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# ((30000, 5, 1), (30000,), (5000, 5, 1), (5000,), (3687, 5, 1), (3687,))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model1 = Sequential()
model1.add(InputLayer((5, 1))) # type: ignore
model1.add(LSTM(64)) # type: ignore
model1.add(Dense(8, 'relu')) # type: ignore
model1.add(Dense(1, 'linear')) # type: ignore

model1.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 64)             │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │           520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,425 (68.07 KB)
#  Trainable params: 17,425 (68.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model1.save("model1.keras")

# %%
cp1 = ModelCheckpoint('model1.keras', save_best_only=True)

# %%
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model1.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=10, callbacks=[cp1])
# Out:
# Epoch 1/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 450.3462 - root_mean_squared_error: 21.1935 - val_loss: 227.7070 - val_root_mean_squared_error: 15.0900
# Epoch 2/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 131.7880 - root_mean_squared_error: 11.4119 - val_loss: 48.4456 - val_root_mean_squared_error: 6.9603
# Epoch 3/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 23.8207 - root_mean_squared_error: 4.8710 - val_loss: 23.3700 - val_root_mean_squared_error: 4.8343
# Epoch 4/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 15.7290 - root_mean_squared_error: 3.9641 - val_loss: 13.8141 - val_root_mean_squared_error: 3.7167
# Epoch 5/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 6.6644 - root_mean_squared_error: 2.5740 - val_loss: 4.7870 - val_root_mean_squared_error: 2.1879
# Epoch 6/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.3017 - root_mean_squared_error: 1.5159 - val_loss: 2.5478 - val_root_mean_squared_error: 1.5962
# Epoch 7/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4277 - root_mean_squared_error: 1.1945 - val_loss: 1.8380 - val_root_mean_squared_error: 1.3557
# Epoch 8/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1529 - root_mean_squared_error: 1.0736 - val_loss: 1.5557 - val_root_mean_squared_error: 1.2473
# Epoch 9/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.0825 - root_mean_squared_error: 1.0403 - val_loss: 1.4415 - val_root_mean_squared_error: 1.2006
# Epoch 10/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.0458 - root_mean_squared_error: 1.0225 - val_loss: 1.4789 - val_root_mean_squared_error: 1.2161

# %%
train_predictions = model1.predict(X_train1).flatten()
train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train1})
train_results
# Out:
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
#        Train Predictions  Actuals
# 0              19.741838     19.6
# 1              19.596077     19.1
# 2              18.962582     19.6
# 3              19.807499     19.8
# 4              19.973429     19.4
# ...                  ...      ...
# 29995          18.555515     18.4
# 29996          18.172180     17.7
# 29997          17.484207     16.6
# 29998          16.362497     16.0
# 29999          15.967429     16.7
#
# [30000 rows x 2 columns]

# %%
plt.plot(train_results['Train Predictions'][50:100], label = 'Train Predictions')
plt.plot(train_results['Actuals'][50:100], label = 'Actuals')
plt.legend(loc='upper right')

# %%
val_predictions = model1.predict(X_val1).flatten()
val_results = pd.DataFrame(data={'Val Predictions':val_predictions, 'Actuals':y_val1})
val_results
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#       Val Predictions  Actuals
# 0           17.213297     16.3
# 1           16.661121     15.5
# 2           15.830219     15.1
# 3           15.505334     16.8
# 4           18.009647     17.8
# ...               ...      ...
# 4995        21.496799     22.4
# 4996        21.562542     21.7
# 4997        20.911104     21.4
# 4998        20.882351     21.2
# 4999        20.833969     21.1
#
# [5000 rows x 2 columns]

# %%
plt.plot(val_results['Val Predictions'][:100], label='Val Predictions')
plt.plot(val_results['Actuals'][:100], label = 'Actuals')
plt.legend(loc='upper right')

# %%
test_predictions = model1.predict(X_test1).flatten()
test_results = pd.DataFrame(data={'Test Predictions':test_predictions, 'Actuals':y_test1})
test_results
# Out:
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#       Test Predictions  Actuals
# 0            20.853573     21.3
# 1            21.223648     21.4
# 2            21.341131     22.0
# 3            22.134396     22.1
# 4            22.075468     22.0
# ...                ...      ...
# 3682         24.992182     25.6
# 3683         24.857166     25.3
# 3684         24.406708     23.9
# 3685         22.773476     22.0
# 3686         20.860977     21.1
#
# [3687 rows x 2 columns]

# %%
plt.plot(test_results['Test Predictions'][:100], label='Test Predictions')
plt.plot(test_results['Actuals'][:100], label='Actuals')
plt.legend(loc='upper right')
